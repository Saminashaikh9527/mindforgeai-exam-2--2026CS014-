# %% [markdown]
# ### **Section D: Data Analytics Interpretation**
#
# **1. Which department appears strongest in the dataset and why?**
#
# **Answer:**
# The Computer Engineeringdepartment is the strongest. Its students have higher readiness scores, good attendance, and better assignment and lab marks.
#
#
#
# **2. Which students need immediate academic support and what signals show that?**
#
# **Answer:**
# Harshada needs academic support. She has low attendance, completed fewer tasks, and has low assignment and lab scores.
#
#
#
# **3. What is one limitation of this small dataset?**
#
# **Answer:**
# The dataset has only 8 students. So, it may not show the performance of all students.
#
#
#
# **4. What extra columns would make the analysis more useful for the internship team?**
#
# **Answer:**
# Some useful extra columns are:
#
# * Exam score
# * Project score
# * Internship attendance
# * Class participation
# * Student feedback or participation
