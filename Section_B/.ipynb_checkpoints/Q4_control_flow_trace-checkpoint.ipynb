# %% [markdown]
# Q4. Control Flow Trace5
#
# Dry-run the following logic for scores 38, 62, 81, and 94. Write the output band for each score.
#
#
# if score < 40:
#
#     band = "Support"
#
# elif score < 70:
#
#     band = "Developing"
#
# elif score < 90:
#
#     band = "Strong"
#
# else:
#
#     band = "Excellent"

# %%
score = int(input("Enter the score: "))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score:  38
# Output Band: Support

# %%
score = int(input("Enter the score: "))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score:  62
# Output Band: Developing

# %%
score = int(input("Enter the score: "))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score:  81
# Output Band: Strong

# %%
score = int(input("Enter the score: "))

if score < 40:
    band = "Support"
elif score < 70:
    band = "Developing"
elif score < 90:
    band = "Strong"
else:
    band = "Excellent"

print("Output Band:", band)
# Out:
# Enter the score:  94
# Output Band: Excellent
